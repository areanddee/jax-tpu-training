# %%
# !git clone https://github.com/areanddee/jax-tpu-training.git
# %cd jax-tpu-training
# %run setup_workspace_hybrid.py
# Out:
# Cloning into 'jax-tpu-training'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 46 (delta 13), reused 7 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (46/46), 21.89 KiB | 10.95 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# /content/jax-tpu-training
# 🛠️  JAX TPU Training Workspace Setup
# 🔄 Hybrid: GitHub + Google Drive
# ----------------------------------------
# 📡 Setting up GitHub repository...
# ✅ Already in repository jax-tpu-training
# 📝 Skipping git operations (already in repo)
# 🔗 Setting up Google Drive access...
# Mounted at /content/drive
# ✅ Google Drive mounted successfully
# 📋 Workspace folders: ['.git', 'Configs', 'Datasets', 'Docs', 'Notebooks', 'Outputs', 'Scripts']
# 🔧 Setting up JAX...
# ✅ JAX already installed (version 0.5.2)
# 🎯 JAX detected: 1 CPU core(s)
#
# ==================================================
# 🚀 WORKSPACE READY!
# ==================================================
# 📍 Current directory: /content/jax-tpu-training
# 📂 Available folders: ['.git', 'Configs', 'Datasets', 'Docs', 'Notebooks', 'Outputs', 'Scripts']
# ☁️  Google Drive: Connected to shared workspace
#
# 📚 Next Steps:
#    1. Start with: Notebooks/01_jax_basics.ipynb
#    2. Check hardware: import jax; print(jax.devices())
#    3. Save work: Ctrl+S to save notebook
#    4. Commit code: !git add . && git commit -m 'your message'
# ==================================================
#
# 🔄 Google Drive sync available:
#    GitHub workspace: /content/jax-tpu-training
#    Google Drive workspace: /content/drive/MyDrive/CoLab-TPU-Projects
#    Use: sync_to_drive() function for manual sync
#
# 💡 Tip: Run sync_to_drive() to copy notebooks to Google Drive

# %%
sync_to_drive()
# Out:
# ✅ Synced Notebooks to Google Drive
# ✅ Synced Scripts to Google Drive
# ✅ Synced Configs to Google Drive
# 🔄 Sync to Google Drive complete!

# %%
# %run Scripts/RK4v_jax_v2.py
